# %%
import pandas as pd

# %%
df = pd.read_csv('data/raw/faostat/turkey_hazelnut_production.csv')

# %%
df.tail(20)
# Out:
#     year  production_mt
# 44  2005       530000.0
# 45  2006       661000.0
# 46  2007       530000.0
# 47  2008       800791.0
# 48  2009       500000.0
# 49  2010       600000.0
# 50  2011       430000.0
# 51  2012       660000.0
# 52  2013       549000.0
# 53  2014       450000.0
# 54  2015       646000.0
# 55  2016       420000.0
# 56  2017       675000.0
# 57  2018       515000.0
# 58  2019       776046.0
# 59  2020       665000.0
# 60  2021       684000.0
# 61  2022       765000.0
# 62  2023       650000.0
# 63  2024       717000.0

# %%
frost = pd.read_csv('data/raw/era5_frost_monthly.csv')

# %%
frost
# Out:
#     year   march_dh   april_dh    frost_dh
# 0   1990   0.817577   0.517844    1.335420
# 1   1991   0.078690   0.000000    0.078690
# 2   1992   7.123327   0.009482    7.132809
# 3   1993   1.014252   1.387186    2.401437
# 4   1994   0.000000   0.058133    0.058133
# 5   1995   4.789377   5.338163   10.127541
# 6   1996   0.000000   0.200153    0.200153
# 7   1997  64.176872  37.235672  101.412544
# 8   1998  22.053326   0.000000   22.053326
# 9   1999   3.186011   0.000000    3.186011
# 10  2000  24.797356   3.523218   28.320574
# 11  2001   0.000000   0.000000    0.000000
# 12  2002   0.003510   0.360858    0.364368
# 13  2003  36.906769   7.198995   44.105762
# 14  2004   0.000000  13.347246   13.347246
# 15  2005   0.731055   2.304846    3.035902
# 16  2006   0.000000   0.028543    0.028543
# 17  2007   0.199612   0.695999    0.895612
# 18  2008   0.514059   0.000000    0.514059
# 19  2009   5.477530   0.016635    5.494164
# 20  2010   1.797433   0.000000    1.797433
# ...

# %%
water = pd.read_csv('data/raw/spei/spei03_era5.csv')

# %%
giresun = pd.read_csv("data/raw/giresun_spot_prices_monthly.csv")
giresun
# Out:
#      crop_year  year  month period  total_qty_kg  total_value_tl  \
# 0         2000  2001      1   full     3603153.0    4.314125e+06
# 1         2000  2001      2   full     3572307.0    4.431059e+06
# 2         2000  2001      3   full     4201042.0    6.142195e+06
# 3         2000  2001      4   full     3770522.0    6.459724e+06
# 4         2000  2001      5   full     1229198.0    2.367189e+06
# ..         ...   ...    ...    ...           ...             ...
# 302       2024  2025      8   open     4212663.0    5.537888e+08
# 303       2024  2024      9   full    19709443.0    2.557915e+09
# 304       2024  2024     10   full    15686118.0    2.024830e+09
# 305       2024  2024     11   full    13817894.0    1.818510e+09
# 306       2024  2024     12   full    14781044.0    1.938562e+09
#
#      total_price_tl_kg  open_qty_kg  open_price_tl  fisko_qty_kg  \
# 0             1.197320    3600459.0       1.197433        2694.0
# ...

# %%
tmo = pd.read_csv("data/raw/hazelnut_35yr_master.csv")

# %%
tmo
# Out:
#     Unnamed: 0    frost_dh   prod_mt     tmo_try  tmo_try_ret  tmo_active  \
# 0         1990    1.335420  375000.0         NaN          NaN         NaN
# 1         1991    0.078690  315000.0         NaN          NaN         NaN
# 2         1992    7.132808  520000.0         NaN          NaN         NaN
# 3         1993    2.401437  305000.0         NaN          NaN         NaN
# 4         1994    0.058133  490000.0         NaN          NaN         NaN
# 5         1995   10.127541  455000.0         NaN          NaN         NaN
# 6         1996    0.200153  446000.0         NaN          NaN         NaN
# 7         1997  101.412576  410000.0         NaN          NaN         NaN
# 8         1998   22.053323  580000.0         NaN          NaN         NaN
# 9         1999    3.186011  530000.0         NaN          NaN         NaN
# 10        2000   28.320576  470000.0         NaN          NaN         0.0
# 11        2001    0.000000  625000.0         NaN          NaN         0.0
# ...

# %%
basket = pd.read_csv("data/raw/basket/basket_dataset.csv")
basket
# Out:
#     year     tmo_eur  hazelnut_eur  almond_eur  walnut_eur
# 0   1985         NaN           NaN         NaN         NaN
# 1   1986         NaN           NaN         NaN         NaN
# 2   1987         NaN           NaN         NaN         NaN
# 3   1988         NaN           NaN         NaN         NaN
# 4   1989         NaN           NaN         NaN         NaN
# 5   1990         NaN           NaN         NaN         NaN
# 6   1991         NaN           NaN         NaN         NaN
# 7   1992         NaN           NaN         NaN         NaN
# 8   1993         NaN           NaN         NaN         NaN
# 9   1994         NaN           NaN         NaN         NaN
# 10  1995         NaN           NaN         NaN         NaN
# 11  1996         NaN           NaN         NaN         NaN
# 12  1997         NaN           NaN         NaN         NaN
# 13  1998         NaN           NaN         NaN         NaN
# 14  1999         NaN           NaN         NaN         NaN
# ...
